# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\GAMANI\Desktop\ML ZoomCamp\Course and Resources\Assignments\ASS_1\raw.githubusercontent.com_alexeygrigorev_datasets_master_housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#grouping all the options located on inland or 1H_OCEAN
inland_options = df[df['ocean_proximity'] == 'INLAND']
inland_options
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 954      -121.92     37.64                46.0       1280.0           209.0
# 957      -121.90     37.66                18.0       7397.0          1137.0
# 965      -121.88     37.68                23.0       2234.0           270.0
# 967      -121.88     37.67                16.0       4070.0           624.0
# 968      -121.88     37.67                25.0       2244.0           301.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
inland_options.drop(columns = ['ocean_proximity'], inplace = True)
# Out:
# C:\Users\GAMANI\AppData\Local\Temp\ipykernel_5212\1027067505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inland_options.drop(columns = ['ocean_proximity'], inplace = True)

# %%
inland_options.isnull().sum()
# Out:
# longitude              0
# latitude               0
# housing_median_age     0
# total_rooms            0
# total_bedrooms        55
# population             0
# households             0
# median_income          0
# median_house_value     0
# dtype: int64

# %%
inland_options.describe()
# Out:
#         longitude     latitude  housing_median_age   total_rooms  \
# count  6551.00000  6551.000000         6551.000000   6551.000000
# mean   -119.73299    36.731829           24.271867   2717.742787
# std       1.90095     2.116073           12.018020   2385.831111
# min    -123.73000    32.640000            1.000000      2.000000
# 25%    -121.35000    34.180000           15.000000   1404.000000
# 50%    -120.00000    36.970000           23.000000   2131.000000
# 75%    -117.84000    38.550000           33.000000   3216.000000
# max    -114.31000    41.950000           52.000000  39320.000000
#
#        total_bedrooms    population   households  median_income  \
# count     6496.000000   6551.000000  6551.000000    6551.000000
# mean       533.881619   1391.046252   477.447565       3.208996
# std        446.117778   1168.670126   392.252095       1.437465
# min          2.000000      5.000000     2.000000       0.499900
# ...

# %%
df = inland_options
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 954      -121.92     37.64                46.0       1280.0           209.0
# 957      -121.90     37.66                18.0       7397.0          1137.0
# 965      -121.88     37.68                23.0       2234.0           270.0
# 967      -121.88     37.67                16.0       4070.0           624.0
# 968      -121.88     37.67                25.0       2244.0           301.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
n = len(df)
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train= n - (n_val + n_test)

# %%
n, n_val, n_test, n_train
# Out:
# (6551, 1310, 1310, 3931)

# %%
df_train = df.iloc[:n_train]
df_val = df.iloc[n_train: n_train + n_val]
df_test = df.iloc[n_train + n_val:]

# %%
len(df_train),len(df_test),len(df_val)
# Out:
# (3931, 1310, 1310)

# %%
idx = np.arange(n)

# %%
np.random.seed(42)
np.random.shuffle(idx)

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train: n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
len(df_train),len(df_test),len(df_val)
# Out:
# (3931, 1310, 1310)

# %%
y_train = np.log1p(df_train.median_house_value)
y_val = np.log1p(df_val.median_house_value)
y_test = np.log1p(df_test.median_house_value)

# %%
del df_train["median_house_value"]
del df_val["median_house_value"]
del df_test["median_house_value"]

# %%
df_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2724     -115.55     32.80                23.0        666.0           142.0
# 2172     -119.85     36.78                 8.0       3096.0           684.0
# 12946    -121.29     38.65                27.0       2744.0           464.0
# 2179     -119.90     36.79                22.0       1970.0           332.0
# 20517    -121.54     38.58                30.0       4648.0          1252.0
#
#        population  households  median_income
# 2724        580.0       160.0         2.1136
# 2172       1454.0       545.0         2.7857
# 12946      1340.0       452.0         3.8816
# 2179       1066.0       319.0         3.3125
# 20517      2524.0      1089.0         1.3177

# %%
len(y_train)
# Out:
# 3931

# %% [markdown]
# # LINEAR REGRESSION

# %%
def linear_regression(xi):
    n = len(xi)
    prediction = w0
    for j in range(n):
        prediction = prediction + w[j] * xi[j]
    return prediction

# %% [markdown]
# # IMPLEMENTING LINEAR REGRESSION IN THE VECTOR FORM

# %%
def dot(xi, w):
    n = len(xi)
    result = 0.0
    for j in range(n):
        result = result + w[j] * xi[j]
    return result

# %%
def linear_regression(xi):
    return dot(xi ,w)

# %% [markdown]
# # TRAINING LINEAR REGRESSION MODEL

# %%
def train_linear_regression(x, y):
    pass

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    
    return w_full[0], w_full[1:]

# %%
train_linear_regression(X, y)

# %% [markdown]
# # HOUSE PRICE BASELINE MODEL

# %%
df_train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income'],
#       dtype='object')

# %%
base = ['longitude', 'latitude', 'housing_median_age',
        'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income']

# %%
mean = df_train['total_bedrooms'].mean()
mean
# Out:
# 531.7447408927655

# %%
# Create two copies of the training data
X_train_1 = df_train[base].fillna(0).values
X_train_2 = df_train[base].fillna(mean).values

# %%
# for the X_train_1 
w0, w = train_linear_regression(X_train_1, y_train)

y_pred = w0 + X_train_1.dot(w)
y_pred
rmse(y_train, y_pred)
# Out:
# 0.33039175218875183

# %%
# for the X_train_2 
w0, w = train_linear_regression(X_train_2, y_train)

y_pred = w0 + X_train_2.dot(w)
y_pred
rmse(y_train, y_pred)
# Out:
# 0.3301619203916573

# %% [markdown]
# # RMSE

# %%
def rmse(y, y_pred):
    se = (y - y_pred) ** 2
    mse = se.mean()
    return np.sqrt(mse)

# %% [markdown]
# # Validating the model

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train_1 = prepare_X(df_train)
w0, w = train_linear_regression(X_train_1, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred).round(2)
# Out:
# 0.33

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(mean)
    X = df_num.values
    return X

# %%
X_train_2 = prepare_X(df_train)
w0, w = train_linear_regression(X_train_2, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred).round(2)
# Out:
# 0.33

# %% [markdown]
# # Simple feature engineering

# %%
df_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2724     -115.55     32.80                23.0        666.0           142.0
# 2172     -119.85     36.78                 8.0       3096.0           684.0
# 12946    -121.29     38.65                27.0       2744.0           464.0
# 2179     -119.90     36.79                22.0       1970.0           332.0
# 20517    -121.54     38.58                30.0       4648.0          1252.0
# ...          ...       ...                 ...          ...             ...
# 16543    -121.23     37.79                23.0       1985.0           424.0
# 9169     -118.61     34.59                 5.0       4028.0           896.0
# 5989     -117.72     34.10                46.0       2477.0           458.0
# 20033    -119.02     36.07                29.0       2610.0           597.0
# 3183     -119.77     36.30                24.0       2202.0           471.0
#
#        population  households  median_income
# ...
